# %%
import pandas as pd
dataset = pd.read_csv("CKD.csv")

# %%
dataset.head()
# Out:
#    age         bp sg   al   su     rbc        pc         pcc          ba  \
# 0  2.0  76.459948  c  3.0  0.0  normal  abnormal  notpresent  notpresent
# 1  3.0  76.459948  c  2.0  0.0  normal    normal  notpresent  notpresent
# 2  4.0  76.459948  a  1.0  0.0  normal    normal  notpresent  notpresent
# 3  5.0  76.459948  d  1.0  0.0  normal    normal  notpresent  notpresent
# 4  5.0  50.000000  c  0.0  0.0  normal    normal  notpresent  notpresent
#
#           bgr  ...        pcv            wc        rc  htn  dm  cad  appet  \
# 0  148.112676  ...  38.868902   8408.191126  4.705597   no  no   no    yes
# 1  148.112676  ...  34.000000  12300.000000  4.705597   no  no   no    yes
# 2   99.000000  ...  34.000000   8408.191126  4.705597   no  no   no    yes
# 3  148.112676  ...  38.868902   8408.191126  4.705597   no  no   no    yes
# 4  148.112676  ...  36.000000  12400.000000  4.705597   no  no   no    yes
#
#      pe  ane classification
# 0   yes   no            yes
# 1  poor   no            yes
# 2  poor   no            yes
# 3  poor  yes            yes
# 4  poor   no            yes
#
# [5 rows x 25 columns]

# %%
dataset.tail()
# Out:
#            age    bp sg   al   su     rbc      pc         pcc          ba  \
# 394  51.492308  70.0  a  0.0  0.0  normal  normal  notpresent  notpresent
# 395  51.492308  70.0  c  0.0  2.0  normal  normal  notpresent  notpresent
# 396  51.492308  70.0  c  3.0  0.0  normal  normal  notpresent  notpresent
# 397  51.492308  90.0  a  0.0  0.0  normal  normal  notpresent  notpresent
# 398  51.492308  80.0  a  0.0  0.0  normal  normal  notpresent  notpresent
#
#        bgr  ...        pcv           wc        rc  htn   dm  cad  appet    pe  \
# 394  219.0  ...  37.000000  9800.000000  4.400000   no   no   no    yes  poor
# 395  220.0  ...  27.000000  8408.191126  4.705597  yes  yes   no    yes  poor
# 396  110.0  ...  26.000000  9200.000000  3.400000  yes  yes   no   poor  poor
# 397  207.0  ...  38.868902  8408.191126  4.705597  yes  yes   no    yes  poor
# 398  100.0  ...  53.000000  8500.000000  4.900000   no   no   no    yes  poor
#
#      ane classification
# 394   no            yes
# 395  yes            yes
# 396   no            yes
# 397  yes            yes
# 398   no             no
#
# [5 rows x 25 columns]

# %%
dataset.isnull().sum()
# Out:
# age               0
# bp                0
# sg                0
# al                0
# su                0
# rbc               0
# pc                0
# pcc               0
# ba                0
# bgr               0
# bu                0
# sc                0
# sod               0
# pot               0
# hrmo              0
# pcv               0
# wc                0
# rc                0
# htn               0
# dm                0
# cad               0
# appet             0
# pe                0
# ane               0
# classification    0
# dtype: int64

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hrmo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
dataset["classification"].value_counts()
# Out:
# classification
# yes    249
# no     150
# Name: count, dtype: int64

# %%
dataset.shape
# Out:
# (399, 25)

# %%
dataset=pd.get_dummies(dataset,drop_first=True,dtype=int)

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
#        'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
#        'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
#        'appet_yes', 'pe_yes', 'ane_yes', 'classification_yes'],
#       dtype='object')

# %%
dataset.drop('age',axis=1,inplace=True)

# %%
dataset.shape
# Out:
# (399, 27)

# %%
dataset.columns
# Out:
# Index(['bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv', 'wc',
#        'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
#        'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
#        'appet_yes', 'pe_yes', 'ane_yes', 'classification_yes'],
#       dtype='object')

# %%
features=dataset[['bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv', 'wc',
       'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']]
target=dataset['classification_yes']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(features,target,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
X_train=ss.fit_transform(X_train)
X_test=ss.transform(X_test)

# %%
X_train.shape
# Out:
# (319, 26)

# %%
X_test.shape
# Out:
# (80, 26)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
params={
    'n_neighbors': [3, 5, 7, 9, 11],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'minkowski'],
    'p': [1, 2],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']
    }
grid=GridSearchCV(KNeighborsClassifier(),params,refit=True,verbose=3,n_jobs=-1,scoring='f1_weighted')

# %%
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 240 candidates, totalling 1200 fits
# GridSearchCV(estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#                          'metric': ['euclidean', 'manhattan', 'minkowski'],
#                          'n_neighbors': [3, 5, 7, 9, 11], 'p': [1, 2],
#                          'weights': ['uniform', 'distance']},
#              scoring='f1_weighted', verbose=3)

# %%
y_pred=grid.predict(X_test)

# %%
grid.best_params_
# Out:
# {'algorithm': 'auto',
#  'metric': 'euclidean',
#  'n_neighbors': 3,
#  'p': 1,
#  'weights': 'uniform'}

# %%
cl=grid.cv_results_

# %%
pd.DataFrame.from_dict(cl)
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.001502      0.000855         0.193356        0.013364
# 1         0.002699      0.001276         0.192646        0.014725
# 2         0.002505      0.001047         0.086675        0.097188
# 3         0.001414      0.000805         0.005641        0.003480
# 4         0.002049      0.001652         0.009706        0.001199
# ..             ...           ...              ...             ...
# 235       0.000943      0.001175         0.003809        0.001461
# 236       0.001791      0.002239         0.002808        0.002920
# 237       0.000668      0.000846         0.003677        0.002057
# 238       0.001147      0.001086         0.004437        0.000321
# 239       0.001587      0.001217         0.004022        0.001173
#
#     param_algorithm param_metric  param_n_neighbors  param_p param_weights  \
# 0              auto    euclidean                  3        1       uniform
# 1              auto    euclidean                  3        1      distance
# 2              auto    euclidean                  3        2       uniform
# 3              auto    euclidean                  3        2      distance
# 4              auto    euclidean                  5        1       uniform
# ..              ...          ...                ...      ...           ...
# 235           brute    minkowski                  9        2      distance
# 236           brute    minkowski                 11        1       uniform
# 237           brute    minkowski                 11        1      distance
# 238           brute    minkowski                 11        2       uniform
# 239           brute    minkowski                 11        2      distance
#
#                                                 params  split0_test_score  \
# 0    {'algorithm': 'auto', 'metric': 'euclidean', '...           0.984445
# 1    {'algorithm': 'auto', 'metric': 'euclidean', '...           0.984445
# 2    {'algorithm': 'auto', 'metric': 'euclidean', '...           0.984445
# 3    {'algorithm': 'auto', 'metric': 'euclidean', '...           0.984445
# 4    {'algorithm': 'auto', 'metric': 'euclidean', '...           0.953670
# ..                                                 ...                ...
# 235  {'algorithm': 'brute', 'metric': 'minkowski', ...           0.923168
# 236  {'algorithm': 'brute', 'metric': 'minkowski', ...           0.969010
# 237  {'algorithm': 'brute', 'metric': 'minkowski', ...           0.969010
# 238  {'algorithm': 'brute', 'metric': 'minkowski', ...           0.907958
# 239  {'algorithm': 'brute', 'metric': 'minkowski', ...           0.907958
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 0             1.000000           0.953307           0.984436
# 1             1.000000           0.953307           0.984436
# 2             1.000000           0.953307           0.984436
# 3             1.000000           0.953307           0.984436
# 4             0.984436           0.953307           0.968974
# ..                 ...                ...                ...
# 235           0.968974           0.953591           0.968974
# 236           0.968974           0.953591           0.968974
# 237           0.968974           0.953591           0.968974
# 238           0.953591           0.953591           0.968974
# 239           0.968974           0.953591           0.968974
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0             1.000000         0.984437        0.017050                1
# 1             1.000000         0.984437        0.017050                1
# 2             1.000000         0.984437        0.017050                1
# 3             1.000000         0.984437        0.017050                1
# 4             1.000000         0.972077        0.018073               73
# ..                 ...              ...             ...              ...
# 235           0.968508         0.956643        0.017747              193
# 236           1.000000         0.972110        0.015166               49
# 237           1.000000         0.972110        0.015166               49
# 238           0.968508         0.950524        0.022336              229
# 239           0.968508         0.953601        0.023572              217
#
# [240 rows x 18 columns]

# %%
grid.best_params_
# Out:
# {'algorithm': 'auto',
#  'metric': 'euclidean',
#  'n_neighbors': 3,
#  'p': 1,
#  'weights': 'uniform'}

# %%
from sklearn.metrics import confusion_matrix,classification_report
cm=confusion_matrix(y_test,y_pred)

# %%
print(cm)
# Out:
# [[31  1]
#  [ 1 47]]

# %%
cf=classification_report(y_test,y_pred)

# %%
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        32
#            1       0.98      0.98      0.98        48
#
#     accuracy                           0.97        80
#    macro avg       0.97      0.97      0.97        80
# weighted avg       0.97      0.97      0.97        80

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
# Out:
# 0.9889322916666666
