# %%
import pandas as pd
dataset = pd.read_csv("CKD.csv")

# %%
dataset.head()
# Out:
#    age         bp sg   al   su     rbc        pc         pcc          ba  \
# 0  2.0  76.459948  c  3.0  0.0  normal  abnormal  notpresent  notpresent
# 1  3.0  76.459948  c  2.0  0.0  normal    normal  notpresent  notpresent
# 2  4.0  76.459948  a  1.0  0.0  normal    normal  notpresent  notpresent
# 3  5.0  76.459948  d  1.0  0.0  normal    normal  notpresent  notpresent
# 4  5.0  50.000000  c  0.0  0.0  normal    normal  notpresent  notpresent
#
#           bgr  ...        pcv            wc        rc  htn  dm  cad  appet  \
# 0  148.112676  ...  38.868902   8408.191126  4.705597   no  no   no    yes
# 1  148.112676  ...  34.000000  12300.000000  4.705597   no  no   no    yes
# 2   99.000000  ...  34.000000   8408.191126  4.705597   no  no   no    yes
# 3  148.112676  ...  38.868902   8408.191126  4.705597   no  no   no    yes
# 4  148.112676  ...  36.000000  12400.000000  4.705597   no  no   no    yes
#
#      pe  ane classification
# 0   yes   no            yes
# 1  poor   no            yes
# 2  poor   no            yes
# 3  poor  yes            yes
# 4  poor   no            yes
#
# [5 rows x 25 columns]

# %%
dataset.tail()
# Out:
#            age    bp sg   al   su     rbc      pc         pcc          ba  \
# 394  51.492308  70.0  a  0.0  0.0  normal  normal  notpresent  notpresent
# 395  51.492308  70.0  c  0.0  2.0  normal  normal  notpresent  notpresent
# 396  51.492308  70.0  c  3.0  0.0  normal  normal  notpresent  notpresent
# 397  51.492308  90.0  a  0.0  0.0  normal  normal  notpresent  notpresent
# 398  51.492308  80.0  a  0.0  0.0  normal  normal  notpresent  notpresent
#
#        bgr  ...        pcv           wc        rc  htn   dm  cad  appet    pe  \
# 394  219.0  ...  37.000000  9800.000000  4.400000   no   no   no    yes  poor
# 395  220.0  ...  27.000000  8408.191126  4.705597  yes  yes   no    yes  poor
# 396  110.0  ...  26.000000  9200.000000  3.400000  yes  yes   no   poor  poor
# 397  207.0  ...  38.868902  8408.191126  4.705597  yes  yes   no    yes  poor
# 398  100.0  ...  53.000000  8500.000000  4.900000   no   no   no    yes  poor
#
#      ane classification
# 394   no            yes
# 395  yes            yes
# 396   no            yes
# 397  yes            yes
# 398   no             no
#
# [5 rows x 25 columns]

# %%
dataset.isnull().sum()
# Out:
# age               0
# bp                0
# sg                0
# al                0
# su                0
# rbc               0
# pc                0
# pcc               0
# ba                0
# bgr               0
# bu                0
# sc                0
# sod               0
# pot               0
# hrmo              0
# pcv               0
# wc                0
# rc                0
# htn               0
# dm                0
# cad               0
# appet             0
# pe                0
# ane               0
# classification    0
# dtype: int64

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hrmo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
dataset["classification"].value_counts()
# Out:
# classification
# yes    249
# no     150
# Name: count, dtype: int64

# %%
dataset.shape
# Out:
# (399, 25)

# %%
dataset=pd.get_dummies(dataset,drop_first=True,dtype=int)

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
#        'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
#        'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
#        'appet_yes', 'pe_yes', 'ane_yes', 'classification_yes'],
#       dtype='object')

# %%
dataset.drop('age',axis=1,inplace=True)

# %%
dataset.shape
# Out:
# (399, 27)

# %%
dataset.columns
# Out:
# Index(['bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv', 'wc',
#        'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
#        'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
#        'appet_yes', 'pe_yes', 'ane_yes', 'classification_yes'],
#       dtype='object')

# %%
features=dataset[['bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv', 'wc',
       'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']]
target=dataset['classification_yes']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(features,target,test_size=0.2,random_state=0)

# %%
X_train.shape
# Out:
# (319, 26)

# %%
X_test.shape
# Out:
# (80, 26)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
params={
    'n_estimators': [50, 100, 200, 300],
    'criterion': ['gini', 'entropy', 'log_loss'],
    'max_depth': [None, 10, 20, 30]
        }
grid=GridSearchCV(RandomForestClassifier(),params,refit=True,verbose=3,n_jobs=-1,scoring='f1_weighted')

# %%
grid
# Out:
# GridSearchCV(estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [None, 10, 20, 30],
#                          'n_estimators': [50, 100, 200, 300]},
#              scoring='f1_weighted', verbose=3)

# %%
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# GridSearchCV(estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [None, 10, 20, 30],
#                          'n_estimators': [50, 100, 200, 300]},
#              scoring='f1_weighted', verbose=3)

# %%
y_pred=grid.predict(X_test)

# %%
grid.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 10, 'n_estimators': 300}

# %%
cl=grid.cv_results_

# %%
pd.DataFrame.from_dict(cl)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.089471      0.003607         0.007303        0.001081
# 1        0.185494      0.024521         0.009937        0.000688
# 2        0.473266      0.067652         0.015327        0.000971
# 3        0.634159      0.081723         0.023956        0.004799
# 4        0.126025      0.058152         0.010839        0.006688
# 5        0.244181      0.048295         0.013969        0.006612
# 6        0.365503      0.012765         0.016319        0.002765
# 7        0.633475      0.100183         0.022407        0.002007
# 8        0.094523      0.004669         0.007750        0.001712
# 9        0.222539      0.058338         0.011275        0.002210
# 10       0.396586      0.065208         0.020149        0.008419
# 11       0.605331      0.070850         0.023191        0.005704
# 12       0.099822      0.013049         0.007285        0.000867
# 13       0.179060      0.006605         0.012042        0.005488
# 14       0.378780      0.031597         0.016075        0.002794
# 15       0.546428      0.022717         0.020151        0.002129
# 16       0.091631      0.002700         0.007528        0.001461
# 17       0.196268      0.018995         0.009974        0.000451
# 18       0.395491      0.014881         0.015567        0.002157
# 19       0.582818      0.053806         0.021663        0.002537
# 20       0.099542      0.008869         0.007852        0.001167
# 21       0.198517      0.014707         0.009921        0.001505
# 22       0.393686      0.015672         0.015834        0.001511
# 23       0.528709      0.012332         0.020261        0.001421
# 24       0.107250      0.014576         0.007827        0.001018
# 25       0.187901      0.009460         0.009628        0.001463
# 26       0.461611      0.037716         0.018413        0.002095
# 27       0.571050      0.057339         0.020501        0.001115
# 28       0.091233      0.001836         0.007065        0.000841
# 29       0.213060      0.036886         0.010314        0.000292
# 30       0.378724      0.024379         0.015083        0.000844
# 31       0.552929      0.025003         0.020754        0.001317
# 32       0.098904      0.005711         0.006563        0.000873
# 33       0.190610      0.010021         0.010394        0.001729
# 34       0.415216      0.058435         0.018413        0.006841
# 35       0.616618      0.070597         0.022310        0.002242
# 36       0.092925      0.002314         0.006513        0.000690
# 37       0.197870      0.018124         0.011147        0.001762
# 38       0.379720      0.013266         0.014697        0.000724
# 39       0.592697      0.070469         0.021510        0.001571
# 40       0.094144      0.004377         0.006615        0.000813
# 41       0.214184      0.020807         0.014206        0.007098
# 42       0.374812      0.015407         0.015942        0.001002
# 43       0.518808      0.036396         0.017589        0.003917
# 44       0.099136      0.004121         0.007189        0.001330
# 45       0.198158      0.016813         0.009595        0.000633
# 46       0.350432      0.057478         0.014212        0.000649
# 47       0.377224      0.103792         0.011201        0.002662
#
#    param_criterion param_max_depth  param_n_estimators  \
# 0             gini            None                  50
# 1             gini            None                 100
# 2             gini            None                 200
# 3             gini            None                 300
# 4             gini              10                  50
# 5             gini              10                 100
# 6             gini              10                 200
# 7             gini              10                 300
# 8             gini              20                  50
# 9             gini              20                 100
# 10            gini              20                 200
# 11            gini              20                 300
# 12            gini              30                  50
# 13            gini              30                 100
# 14            gini              30                 200
# 15            gini              30                 300
# 16         entropy            None                  50
# 17         entropy            None                 100
# 18         entropy            None                 200
# 19         entropy            None                 300
# 20         entropy              10                  50
# 21         entropy              10                 100
# 22         entropy              10                 200
# 23         entropy              10                 300
# 24         entropy              20                  50
# 25         entropy              20                 100
# 26         entropy              20                 200
# 27         entropy              20                 300
# 28         entropy              30                  50
# 29         entropy              30                 100
# 30         entropy              30                 200
# 31         entropy              30                 300
# 32        log_loss            None                  50
# 33        log_loss            None                 100
# 34        log_loss            None                 200
# 35        log_loss            None                 300
# 36        log_loss              10                  50
# 37        log_loss              10                 100
# 38        log_loss              10                 200
# 39        log_loss              10                 300
# 40        log_loss              20                  50
# 41        log_loss              20                 100
# 42        log_loss              20                 200
# 43        log_loss              20                 300
# 44        log_loss              30                  50
# 45        log_loss              30                 100
# 46        log_loss              30                 200
# 47        log_loss              30                 300
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'gini', 'max_depth': None, 'n_es...           0.984445
# 1   {'criterion': 'gini', 'max_depth': None, 'n_es...           0.984445
# 2   {'criterion': 'gini', 'max_depth': None, 'n_es...           0.984445
# 3   {'criterion': 'gini', 'max_depth': None, 'n_es...           0.984445
# 4   {'criterion': 'gini', 'max_depth': 10, 'n_esti...           0.984445
# 5   {'criterion': 'gini', 'max_depth': 10, 'n_esti...           0.984445
# 6   {'criterion': 'gini', 'max_depth': 10, 'n_esti...           1.000000
# 7   {'criterion': 'gini', 'max_depth': 10, 'n_esti...           0.984445
# 8   {'criterion': 'gini', 'max_depth': 20, 'n_esti...           0.984445
# 9   {'criterion': 'gini', 'max_depth': 20, 'n_esti...           0.984445
# 10  {'criterion': 'gini', 'max_depth': 20, 'n_esti...           0.984445
# 11  {'criterion': 'gini', 'max_depth': 20, 'n_esti...           0.984445
# 12  {'criterion': 'gini', 'max_depth': 30, 'n_esti...           0.984445
# 13  {'criterion': 'gini', 'max_depth': 30, 'n_esti...           0.984445
# 14  {'criterion': 'gini', 'max_depth': 30, 'n_esti...           0.984445
# 15  {'criterion': 'gini', 'max_depth': 30, 'n_esti...           0.984445
# 16  {'criterion': 'entropy', 'max_depth': None, 'n...           0.984445
# 17  {'criterion': 'entropy', 'max_depth': None, 'n...           0.984445
# 18  {'criterion': 'entropy', 'max_depth': None, 'n...           0.984445
# 19  {'criterion': 'entropy', 'max_depth': None, 'n...           0.984445
# 20  {'criterion': 'entropy', 'max_depth': 10, 'n_e...           0.984445
# 21  {'criterion': 'entropy', 'max_depth': 10, 'n_e...           0.984445
# 22  {'criterion': 'entropy', 'max_depth': 10, 'n_e...           0.984445
# 23  {'criterion': 'entropy', 'max_depth': 10, 'n_e...           0.984445
# 24  {'criterion': 'entropy', 'max_depth': 20, 'n_e...           0.984445
# 25  {'criterion': 'entropy', 'max_depth': 20, 'n_e...           0.984445
# 26  {'criterion': 'entropy', 'max_depth': 20, 'n_e...           0.984445
# 27  {'criterion': 'entropy', 'max_depth': 20, 'n_e...           0.984445
# 28  {'criterion': 'entropy', 'max_depth': 30, 'n_e...           0.984445
# 29  {'criterion': 'entropy', 'max_depth': 30, 'n_e...           0.984445
# 30  {'criterion': 'entropy', 'max_depth': 30, 'n_e...           0.984445
# 31  {'criterion': 'entropy', 'max_depth': 30, 'n_e...           0.984445
# 32  {'criterion': 'log_loss', 'max_depth': None, '...           0.984445
# 33  {'criterion': 'log_loss', 'max_depth': None, '...           0.984445
# 34  {'criterion': 'log_loss', 'max_depth': None, '...           0.984445
# 35  {'criterion': 'log_loss', 'max_depth': None, '...           0.984445
# 36  {'criterion': 'log_loss', 'max_depth': 10, 'n_...           0.984445
# 37  {'criterion': 'log_loss', 'max_depth': 10, 'n_...           0.984445
# 38  {'criterion': 'log_loss', 'max_depth': 10, 'n_...           0.984445
# 39  {'criterion': 'log_loss', 'max_depth': 10, 'n_...           0.984445
# 40  {'criterion': 'log_loss', 'max_depth': 20, 'n_...           0.984445
# 41  {'criterion': 'log_loss', 'max_depth': 20, 'n_...           0.984445
# 42  {'criterion': 'log_loss', 'max_depth': 20, 'n_...           0.984445
# 43  {'criterion': 'log_loss', 'max_depth': 20, 'n_...           0.984445
# 44  {'criterion': 'log_loss', 'max_depth': 30, 'n_...           0.984445
# 45  {'criterion': 'log_loss', 'max_depth': 30, 'n_...           0.984445
# 46  {'criterion': 'log_loss', 'max_depth': 30, 'n_...           0.984445
# 47  {'criterion': 'log_loss', 'max_depth': 30, 'n_...           0.984445
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.968750           0.984436           0.984305
# 1            0.952916           0.984436           0.984305
# 2            0.984305           0.984436           0.984305
# 3            0.952916           0.984436           0.968750
# 4            0.952916           0.953591           0.984305
# 5            0.984305           0.984436           0.968750
# 6            0.968452           0.968974           0.984305
# 7            0.984305           0.984436           0.968750
# 8            0.984305           0.968974           0.968750
# 9            0.952916           0.984436           0.984305
# 10           0.968750           0.984436           0.984305
# 11           0.968452           0.984436           0.968750
# 12           0.968452           0.984436           0.984305
# 13           0.968452           0.984436           0.984305
# 14           0.968750           0.984436           0.984305
# 15           0.984305           0.984436           0.984305
# 16           0.984305           0.968974           0.968750
# 17           0.984305           0.968974           0.984305
# 18           0.952916           0.953591           0.984305
# 19           0.968452           0.953591           0.984305
# 20           0.968750           1.000000           0.968750
# 21           0.968452           0.968974           0.968750
# 22           0.952916           0.968974           0.984305
# 23           0.984305           0.984436           0.984305
# 24           0.968452           0.953591           0.984305
# 25           0.968452           0.984436           0.984305
# 26           0.968452           0.968974           0.984305
# 27           0.968452           0.984436           0.984305
# 28           0.952916           0.984436           0.968750
# 29           0.968452           0.968974           0.984305
# 30           0.968452           0.984436           0.968750
# 31           0.968452           0.968974           0.984305
# 32           0.984305           0.984436           0.968750
# 33           0.952916           0.984436           0.984305
# 34           0.968452           0.968974           0.984305
# 35           0.984305           0.984436           0.984305
# 36           0.968452           0.953591           0.984305
# 37           0.952916           0.953591           0.968750
# 38           0.968452           0.968974           0.984305
# 39           0.968452           0.984436           0.984305
# 40           0.952916           0.984436           0.968750
# 41           0.952916           0.968974           0.984305
# 42           0.968750           0.984436           0.968750
# 43           0.968452           0.968974           0.984305
# 44           0.968452           0.968974           0.984305
# 45           0.952916           1.000000           0.984305
# 46           0.968452           0.984436           0.968750
# 47           0.952916           0.968974           0.984305
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            1.000000         0.984387        0.009882                3
# 1            0.984049         0.978030        0.012558               38
# 2            0.984049         0.984308        0.000143                7
# 3            0.984049         0.974919        0.012545               45
# 4            0.984049         0.971861        0.015195               48
# 5            0.984049         0.981197        0.006225               19
# 6            0.984049         0.981156        0.011689               24
# 7            0.984049         0.981197        0.006225               19
# 8            0.984049         0.978105        0.007548               33
# 9            0.984049         0.978030        0.012558               38
# 10           0.984049         0.981197        0.006225               19
# 11           0.984049         0.978026        0.007698               40
# 12           0.984049         0.981137        0.006344               26
# 13           1.000000         0.984327        0.009977                4
# 14           0.984049         0.981197        0.006225               19
# 15           0.984049         0.984308        0.000143                7
# 16           0.984049         0.978105        0.007548               33
# 17           0.984049         0.981216        0.006122               17
# 18           1.000000         0.975051        0.018691               41
# 19           1.000000         0.978158        0.015825               28
# 20           0.984049         0.981199        0.011680               18
# 21           0.984049         0.974934        0.007607               44
# 22           0.984049         0.974938        0.012503               42
# 23           1.000000         0.987498        0.006251                1
# 24           1.000000         0.978158        0.015825               28
# 25           0.984049         0.981137        0.006344               26
# 26           0.984049         0.978045        0.007622               35
# 27           1.000000         0.984327        0.009977                4
# 28           0.984049         0.974919        0.012545               45
# 29           1.000000         0.981235        0.011710               10
# 30           1.000000         0.981216        0.011764               15
# 31           1.000000         0.981235        0.011710               10
# 32           0.984049         0.981197        0.006225               19
# 33           1.000000         0.981220        0.015389               14
# 34           0.984049         0.978045        0.007622               35
# 35           1.000000         0.987498        0.006251                1
# 36           1.000000         0.978158        0.015825               28
# 37           1.000000         0.971940        0.018180               47
# 38           1.000000         0.981235        0.011710               10
# 39           1.000000         0.984327        0.009977                4
# 40           1.000000         0.978109        0.016010               32
# 41           0.984049         0.974938        0.012503               42
# 42           1.000000         0.981276        0.011700                9
# 43           1.000000         0.981235        0.011710               10
# 44           0.984049         0.978045        0.007622               35
# 45           0.984049         0.981143        0.015373               25
# 46           1.000000         0.981216        0.011764               15
# 47           1.000000         0.978128        0.015974               31

# %%
from sklearn.metrics import confusion_matrix,classification_report
cm=confusion_matrix(y_test,y_pred)

# %%
print(cm)
# Out:
# [[31  1]
#  [ 0 48]]

# %%
cf=classification_report(y_test,y_pred)

# %%
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98        32
#            1       0.98      1.00      0.99        48
#
#     accuracy                           0.99        80
#    macro avg       0.99      0.98      0.99        80
# weighted avg       0.99      0.99      0.99        80

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
# Out:
# 1.0
